# %%
import sys
sys.path.insert(0, '../../')

# %%
import backtrader as bt
import pandas as pd
import numpy as np
import datetime
from tqdm import tqdm
from copy import deepcopy

# %% [markdown]
# # 小试一下

# %%
# 实例化 cerebro
cerebro = bt.Cerebro()
# 打印初始资金
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
# 启动回测
cerebro.run()
# 打印回测完成后的资金
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 10000.00
# Final Portfolio Value: 10000.00

# %% [markdown]
# # 一、数据准备

# %% [markdown]
# ## 1.1 读取日度行情表
#
# 表内字段就是 Backtrader 默认情况下要求输入的 7 个字段： 'datetime' 、'open'、'high'、'low'、'close'、'volume'、'openinterest'，外加一个 'sec_code' 股票代码字段。
#
# ---
#
# ### 什么是 `openinterest`（未平仓合约量）？
#
# - **`openinterest`** 是“未平仓合约数量”的意思，主要用于 **期货（futures）和期权（options）** 市场。
# - 它表示到目前为止，市场上还有多少份**尚未平仓或交割的合约**。
#   - 当有新的买家和卖家开立新仓位时，`openinterest` 会**增加**。
#   - 当已有交易者平仓（买入方卖出或卖出方买回）时，`openinterest` 会**减少**。
#
# ---
#
# ### 为什么 Backtrader 要求这个字段？
#
# - Backtrader 是一个通用的回测框架，不仅支持股票，也支持期货、期权等衍生品。
# - 因此，它默认的数据格式中包含了 `openinterest` 这一列，以兼容衍生品数据。
#
# ---
#
# ### 如果我只做股票交易，怎么办？
#
# - **股票没有“未平仓合约”这个概念**，所以对股票来说，`openinterest` **没有意义**。
# - 在这种情况下，你应该将 `openinterest` 列全部设为 **0**。
# - 例如，在你的代码中这样处理是完全正确的：
#   ```python
#   data_.loc[:, ['volume', 'openinterest']] = data_.loc[:, ['volume', 'openinterest']].fillna(0)
#   ```
#
# ---
#
# ### 总结
#
# | 市场类型 | 是否需要 `openinterest` | 建议值 |
# |--------|------------------|-------|
# | 股票（A股、美股等） | ❌ 不需要 | 填 `0` |
# | 期货、期权 | ✅ 需要 | 填真实数据 |
#
# 所以，如果你只交易股票，完全可以忽略 `openinterest`，把它设为 0 即可，不会影响回测结果。

# %%
daily_price = pd.read_csv("../../datas/daily_price.csv", parse_dates=['datetime'])
daily_price.head()
# Out:
#     datetime   sec_code        open        high         low       close  \
# 0 2019-01-02  600466.SH   33.064891   33.496709   31.954503   32.386321
# 1 2019-01-02  603228.SH   50.660230   51.458513   50.394136   51.120778
# 2 2019-01-02  600315.SH  148.258423  150.480132  148.258423  149.558935
# 3 2019-01-02  000750.SZ   49.512579   53.154883   48.715825   51.561375
# 4 2019-01-02  002588.SZ   36.608672   36.608672   35.669988   35.763857
#
#       volume  openinterest
# 0   10629352             0
# 1     426147             0
# 2    2138556             0
# 3  227557612             0
# 4    2841517             0

# %%
daily_price.query("sec_code=='600466.SH'").head()
# Out:
#        datetime   sec_code       open       high        low      close  \
# 0    2019-01-02  600466.SH  33.064891  33.496709  31.954503  32.386321
# 546  2019-01-03  600466.SH  32.262944  32.941515  31.399309  31.831127
# 1211 2019-01-04  600466.SH  31.399309  33.558397  31.337621  33.496709
# 1700 2019-01-07  600466.SH  33.496709  34.360344  33.373332  33.620085
# 2136 2019-01-08  600466.SH  33.311644  34.113591  32.694762  33.743462
#
#         volume  openinterest
# 0     10629352             0
# 546    8602646             0
# 1211  12768116             0
# 1700  10584321             0
# 2136  10012902             0

# %%
# 以 datetime 为 index，类型为 datetime 或 date 类型，Datafeeds 默认情况下是将 index 匹配给 datetime 字段；
daily_price = daily_price.set_index(['datetime'])

# %% [markdown]
# ## 1.2 读取调仓信息表
#
# 表内数据说明：
#
# + trade_date： 调仓期（每月最后一个交易日）;
#
# + sec_code：持仓成分股；
#
# + weight：持仓权重。

# %%
trade_info = pd.read_csv("../../datas/trade_info.csv", parse_dates=['trade_date'])
trade_info.head()
# Out:
#   trade_date   sec_code    weight
# 0 2019-01-31  000006.SZ  0.007282
# 1 2019-01-31  000008.SZ  0.009783
# 2 2019-01-31  000025.SZ  0.006928
# 3 2019-01-31  000090.SZ  0.007234
# 4 2019-01-31  000536.SZ  0.003536

# %% [markdown]
# # 二、 选股回测
#
#  选股策略：定期按持仓权重调仓 。

# %%
# 回测策略
class TestStrategy(bt.Strategy):
    params = (
        ('buy_stocks', None), # 传入各个调仓日的股票列表和相应的权重
    )
    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('{}, {}'.format(dt.isoformat(), txt))

    def __init__(self):
         # 读取调仓日期，即每月的最后一个交易日，回测时，会在这一天下单，然后在下一个交易日，以开盘价买入
        self.trade_dates = pd.to_datetime(self.p.buy_stocks['trade_date'].unique()).date.tolist()
        self.buy_stock = self.p.buy_stocks # 保留调仓信息
        self.order_list = []  # 记录以往订单，在调仓日要全部取消未成交的订单
        self.buy_stocks_pre = [] # 记录上一期持仓
    
    def next(self):
        # 获取当前的回测时间点
        dt = self.datas[0].datetime.date(0)
        # 打印当前时刻的总资产
        self.log('当前总资产 %.2f' %(self.broker.getvalue()))
        # 如果是调仓日，则进行调仓操作
        if dt in self.trade_dates:
            print("--------------{} 为调仓日----------".format(dt))
            #取消之前所下的没成交也未到期的订单
            if len(self.order_list) > 0:
                print("--------------- 撤销未完成的订单 -----------------")
                for od in self.order_list:
                    # 如果订单未完成，则撤销订单
                    self.cancel(od) 
                 #重置订单列表
                self.order_list = [] 
                
            # 提取当前调仓日的持仓列表
            # 对于简单条件（如单值筛选），直接使用布尔索引（df[df['col'] == value]）通常更快、更清晰
            buy_stocks_data = self.buy_stock[self.buy_stock['trade_date'] == pd.Timestamp(dt)]
            #buy_stocks_data = self.buy_stock.query(f"trade_date=='{dt.isoformat()}'")
            long_list = buy_stocks_data['sec_code'].tolist()
            print('long_list', long_list)  # 打印持仓列表
            
            # 对现有持仓中，调仓后不再继续持有的股票进行卖出平仓
            sell_stock = [i for i in self.buy_stocks_pre if i not in long_list]
            print('sell_stock', sell_stock)
            if len(sell_stock) > 0:
                print("-----------对不再持有的股票进行平仓--------------")
                for stock in sell_stock:
                    data = self.getdatabyname(stock)
                    if self.getposition(data).size > 0 :
                        od = self.close(data=data)  
                        self.order_list.append(od) # 记录卖出订单

            # 买入此次调仓的股票：多退少补原则
            print("-----------买入此次调仓期的股票--------------")
            for stock in long_list:
                w = buy_stocks_data.query(f"sec_code=='{stock}'")['weight'].iloc[0] # 提取持仓权重
                data = self.getdatabyname(stock)
                order = self.order_target_percent(data=data, target=w*0.95) # 为减少可用资金不足的情况，留 5% 的现金做备用
                self.order_list.append(order)
                
            self.buy_stocks_pre = long_list  # 保存此次调仓的股票列表
        
    #订单日志    
    def notify_order(self, order):
        # 未被处理的订单
        if order.status in [order.Submitted, order.Accepted]:
            return
        # 已被处理的订单
        if order.status in [order.Completed, order.Canceled, order.Margin]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, ref:%.0f，Price: %.2f, Cost: %.2f, Comm %.2f, Size: %.2f, Stock: %s' %
                    (order.ref,
                     order.executed.price,
                     order.executed.value,
                     order.executed.comm,
                     order.executed.size,
                     order.data._name))
            else:  # Sell
                self.log('SELL EXECUTED, ref:%.0f, Price: %.2f, Cost: %.2f, Comm %.2f, Size: %.2f, Stock: %s' %
                        (order.ref,
                         order.executed.price,
                         order.executed.value,
                         order.executed.comm,
                         order.executed.size,
                         order.data._name))

# %%
# 实例化大脑
cerebro_ = bt.Cerebro() 

# 按股票代码，依次循环传入数据
for stock in tqdm(daily_price['sec_code'].unique()):
    # 日期对齐
    data = pd.DataFrame(index=daily_price.index.unique())
    df = daily_price.query(f"sec_code=='{stock}'")[['open','high','low','close','volume','openinterest']]
    data_ = pd.merge(data, df, left_index=True, right_index=True, how='left')
    data_.loc[:,['volume','openinterest']] = data_.loc[:,['volume','openinterest']].fillna(0)
    data_.loc[:,['open','high','low','close']] = data_.loc[:,['open','high','low','close']].ffill()
    data_.loc[:,['open','high','low','close']] = data_.loc[:,['open','high','low','close']].fillna(0)
    datafeed = bt.feeds.PandasData(dataname=data_, fromdate=datetime.datetime(2019,1,2), todate=datetime.datetime(2021,1,28))
    cerebro_.adddata(datafeed, name=stock)
print(f"All stock Done !")
# Out:
# 100%|██████████| 510/510 [00:06<00:00, 76.52it/s]
# All stock Done !

# %%
cerebro = deepcopy(cerebro_)  # 深度复制已经导入数据的 cerebro_，避免重复导入数据 
# 初始资金 100,000,000    
cerebro.broker.setcash(100000.0) 
# 佣金，双边各 0.0003
cerebro.broker.setcommission(commission=0.0003) 
# 滑点：双边各 0.0001
cerebro.broker.set_slippage_perc(perc=0.0001) 
# 添加策略
cerebro.addstrategy(TestStrategy, buy_stocks=trade_info) # 通过修改参数 buy_stocks ，使用同一策略回测不同的持仓列表
# 添加分析器
cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='pnl') # 返回收益率时序数据
cerebro.addanalyzer(bt.analyzers.AnnualReturn, _name='_AnnualReturn')
cerebro.addanalyzer(bt.analyzers.SharpeRatio, riskfreerate=0.003, annualize=True, _name='_SharpeRatio')
cerebro.addanalyzer(bt.analyzers.DrawDown, _name='_DrawDown')
# 添加观测器
cerebro.addobserver(bt.observers.Value)  # 查看账户资产变动

# 启动回测
result = cerebro.run()
# Out:
# 2019-01-02, 当前总资产 100000.00
# 2019-01-03, 当前总资产 100000.00
# 2019-01-04, 当前总资产 100000.00
# 2019-01-07, 当前总资产 100000.00
# 2019-01-08, 当前总资产 100000.00
# 2019-01-09, 当前总资产 100000.00
# 2019-01-10, 当前总资产 100000.00
# 2019-01-11, 当前总资产 100000.00
# 2019-01-14, 当前总资产 100000.00
# 2019-01-15, 当前总资产 100000.00
# 2019-01-16, 当前总资产 100000.00
# 2019-01-17, 当前总资产 100000.00
# 2019-01-18, 当前总资产 100000.00
# 2019-01-21, 当前总资产 100000.00
# 2019-01-22, 当前总资产 100000.00
# 2019-01-23, 当前总资产 100000.00
# 2019-01-24, 当前总资产 100000.00
# 2019-01-25, 当前总资产 100000.00
# 2019-01-28, 当前总资产 100000.00
# 2019-01-29, 当前总资产 100000.00
# 2019-01-30, 当前总资产 100000.00
# 2019-01-31, 当前总资产 100000.00
# --------------2019-01-31 为调仓日----------
# long_list ['000006.SZ', '000008.SZ', '000025.SZ', '000090.SZ', '000536.SZ', '000587.SZ', '000598.SZ', '000612.SZ', '000636.SZ', '000656.SZ', '000690.SZ', '000712.SZ', '000766.SZ', '000807.SZ', '000829.SZ', '000877.SZ', '000980.SZ', '000999.SZ', '002002.SZ', '002048.SZ', '002051.SZ', '002074.SZ', '002110.SZ', '002127.SZ', '002128.SZ', '002131.SZ', '002152.SZ', '002195.SZ', '002308.SZ', '002358.SZ', '002359.SZ', '002375.SZ', '002400.SZ', '002408.SZ', '002437.SZ', '002463.SZ', '002465.SZ', '002642.SZ', '002707.SZ', '002745.SZ', '002818.SZ', '300001.SZ', '300010.SZ', '300058.SZ', '300113.SZ', '300146.SZ', '300166.SZ', '300266.SZ', '300376.SZ', '300450.SZ', '600006.SH', '600039.SH', '600053.SH', '600056.SH', '600062.SH', '600141.SH', '600151.SH', '600158.SH', '600169.SH', '600259.SH', '600260.SH', '600280.SH', '600366.SH', '600373.SH', '600392.SH', '600393.SH', '600428.SH', '600478.SH', '600500.SH', '600525.SH', '600528.SH', '600582.SH', '600598.SH', '600643.SH', '600657.SH', '600729.SH', '600737.SH', '600765.SH', '600801.SH', '600808.SH', '600820.SH', '600859.SH', '600872.SH', '600875.SH', '600885.SH', '600939.SH', '600970.SH', '601019.SH', '601020.SH', '601168.SH', '601801.SH', '603225.SH', '603233.SH', '603355.SH', '603515.SH', '603568.SH', '603816.SH', '603877.SH', '603883.SH', '603885.SH']
# sell_stock []
# -----------买入此次调仓期的股票--------------
# 2019-02-01, BUY EXECUTED, ref:5691，Price: 177.31, Cost: 531.93, Comm 0.16, Size: 3.00, Stock: 000006.SZ
# 2019-02-01, BUY EXECUTED, ref:5692，Price: 81.76, Cost: 899.32, Comm 0.27, Size: 11.00, Stock: 000008.SZ
# 2019-02-01, BUY EXECUTED, ref:5693，Price: 46.15, Cost: 646.14, Comm 0.19, Size: 14.00, Stock: 000025.SZ
# 2019-02-01, BUY EXECUTED, ref:5694，Price: 25.11, Cost: 678.10, Comm 0.20, Size: 27.00, Stock: 000090.SZ
# 2019-02-01, BUY EXECUTED, ref:5695，Price: 6.13, Cost: 331.29, Comm 0.10, Size: 54.00, Stock: 000536.SZ
# 2019-02-01, BUY EXECUTED, ref:5696，Price: 30.00, Cost: 269.96, Comm 0.08, Size: 9.00, Stock: 000587.SZ
# 2019-02-01, BUY EXECUTED, ref:5697，Price: 103.05, Cost: 1236.57, Comm 0.37, Size: 12.00, Stock: 000598.SZ
# 2019-02-01, BUY EXECUTED, ref:5698，Price: 36.84, Cost: 442.10, Comm 0.13, Size: 12.00, Stock: 000612.SZ
# 2019-02-01, BUY EXECUTED, ref:5699，Price: 172.78, Cost: 863.90, Comm 0.26, Size: 5.00, Stock: 000636.SZ
# 2019-02-01, BUY EXECUTED, ref:5700，Price: 35.60, Cost: 3026.35, Comm 0.91, Size: 85.00, Stock: 000656.SZ
# 2019-02-01, BUY EXECUTED, ref:5701，Price: 257.67, Cost: 1288.33, Comm 0.39, Size: 5.00, Stock: 000690.SZ
# 2019-02-01, BUY EXECUTED, ref:5702，Price: 122.06, Cost: 732.34, Comm 0.22, Size: 6.00, Stock: 000712.SZ
# 2019-02-01, BUY EXECUTED, ref:5703，Price: 19.81, Cost: 336.70, Comm 0.10, Size: 17.00, Stock: 000766.SZ
# 2019-02-01, BUY EXECUTED, ref:5704，Price: 23.95, Cost: 838.16, Comm 0.25, Size: 35.00, Stock: 000807.SZ
# 2019-02-01, BUY EXECUTED, ref:5705，Price: 69.74, Cost: 418.42, Comm 0.13, Size: 6.00, Stock: 000829.SZ
# 2019-02-01, BUY EXECUTED, ref:5706，Price: 49.87, Cost: 698.15, Comm 0.21, Size: 14.00, Stock: 000877.SZ
# 2019-02-01, BUY EXECUTED, ref:5707，Price: 8.42, Cost: 496.53, Comm 0.15, Size: 59.00, Stock: 000980.SZ
# 2019-02-01, BUY EXECUTED, ref:5708，Price: 43.75, Cost: 2143.74, Comm 0.64, Size: 49.00, Stock: 000999.SZ
# 2019-02-01, BUY EXECUTED, ref:5709，Price: 37.05, Cost: 889.17, Comm 0.27, Size: 24.00, Stock: 002002.SZ
# 2019-02-01, BUY EXECUTED, ref:5710，Price: 65.20, Cost: 521.57, Comm 0.16, Size: 8.00, Stock: 002048.SZ
# 2019-02-01, BUY EXECUTED, ref:5711，Price: 58.03, Cost: 1218.60, Comm 0.37, Size: 21.00, Stock: 002051.SZ
# 2019-02-01, BUY EXECUTED, ref:5712，Price: 54.76, Cost: 1204.68, Comm 0.36, Size: 22.00, Stock: 002074.SZ
# 2019-02-01, BUY EXECUTED, ref:5713，Price: 16.67, Cost: 883.34, Comm 0.27, Size: 53.00, Stock: 002110.SZ
# 2019-02-01, BUY EXECUTED, ref:5714，Price: 92.21, Cost: 1659.77, Comm 0.50, Size: 18.00, Stock: 002127.SZ
# 2019-02-01, BUY EXECUTED, ref:5715，Price: 19.18, Cost: 1208.32, Comm 0.36, Size: 63.00, Stock: 002128.SZ
# 2019-02-01, BUY EXECUTED, ref:5716，Price: 55.88, Cost: 447.01, Comm 0.13, Size: 8.00, Stock: 002131.SZ
# 2019-02-01, BUY EXECUTED, ref:5717，Price: 84.49, Cost: 1013.93, Comm 0.30, Size: 12.00, Stock: 002152.SZ
# 2019-02-01, BUY EXECUTED, ref:5718，Price: 79.79, Cost: 1516.02, Comm 0.45, Size: 19.00, Stock: 002195.SZ
# 2019-02-01, BUY EXECUTED, ref:5719，Price: 17.51, Cost: 350.21, Comm 0.11, Size: 20.00, Stock: 002308.SZ
# 2019-02-01, BUY EXECUTED, ref:5720，Price: 147.22, Cost: 1472.23, Comm 0.44, Size: 10.00, Stock: 002358.SZ
# 2019-02-01, BUY EXECUTED, ref:5721，Price: 33.61, Cost: 436.99, Comm 0.13, Size: 13.00, Stock: 002359.SZ
# 2019-02-01, BUY EXECUTED, ref:5722，Price: 32.38, Cost: 647.53, Comm 0.19, Size: 20.00, Stock: 002375.SZ
# 2019-02-01, BUY EXECUTED, ref:5723，Price: 52.56, Cost: 473.02, Comm 0.14, Size: 9.00, Stock: 002400.SZ
# 2019-02-01, BUY EXECUTED, ref:5724，Price: 37.83, Cost: 1059.11, Comm 0.32, Size: 28.00, Stock: 002408.SZ
# 2019-02-01, BUY EXECUTED, ref:5725，Price: 41.58, Cost: 540.56, Comm 0.16, Size: 13.00, Stock: 002437.SZ
# 2019-02-01, BUY EXECUTED, ref:5726，Price: 22.03, Cost: 1343.60, Comm 0.40, Size: 61.00, Stock: 002463.SZ
# 2019-02-01, BUY EXECUTED, ref:5727，Price: 51.13, Cost: 1584.99, Comm 0.48, Size: 31.00, Stock: 002465.SZ
# 2019-02-01, BUY EXECUTED, ref:5728，Price: 23.16, Cost: 254.75, Comm 0.08, Size: 11.00, Stock: 002642.SZ
# 2019-02-01, BUY EXECUTED, ref:5729，Price: 63.60, Cost: 254.40, Comm 0.08, Size: 4.00, Stock: 002707.SZ
# 2019-02-01, BUY EXECUTED, ref:5730，Price: 23.41, Cost: 585.17, Comm 0.18, Size: 25.00, Stock: 002745.SZ
# 2019-02-01, BUY EXECUTED, ref:5731，Price: 22.91, Cost: 183.26, Comm 0.05, Size: 8.00, Stock: 002818.SZ
# 2019-02-01, BUY EXECUTED, ref:5732，Price: 122.71, Cost: 1595.19, Comm 0.48, Size: 13.00, Stock: 300001.SZ
# 2019-02-01, BUY EXECUTED, ref:5733，Price: 36.57, Cost: 475.41, Comm 0.14, Size: 13.00, Stock: 300010.SZ
# 2019-02-01, BUY EXECUTED, ref:5734，Price: 72.35, Cost: 578.83, Comm 0.17, Size: 8.00, Stock: 300058.SZ
# 2019-02-01, BUY EXECUTED, ref:5735，Price: 139.64, Cost: 558.57, Comm 0.17, Size: 4.00, Stock: 300113.SZ
# 2019-02-01, BUY EXECUTED, ref:5736，Price: 465.31, Cost: 1395.93, Comm 0.42, Size: 3.00, Stock: 300146.SZ
# 2019-02-01, BUY EXECUTED, ref:5737，Price: 220.83, Cost: 883.32, Comm 0.26, Size: 4.00, Stock: 300166.SZ
# 2019-02-01, BUY EXECUTED, ref:5738，Price: 57.26, Cost: 400.80, Comm 0.12, Size: 7.00, Stock: 300266.SZ
# 2019-02-01, BUY EXECUTED, ref:5739，Price: 97.83, Cost: 978.32, Comm 0.29, Size: 10.00, Stock: 300376.SZ
# 2019-02-01, BUY EXECUTED, ref:5740，Price: 362.13, Cost: 1086.40, Comm 0.33, Size: 3.00, Stock: 300450.SZ
# 2019-02-01, BUY EXECUTED, ref:5741，Price: 13.06, Cost: 731.32, Comm 0.22, Size: 56.00, Stock: 600006.SH
# 2019-02-01, BUY EXECUTED, ref:5742，Price: 24.98, Cost: 1124.15, Comm 0.34, Size: 45.00, Stock: 600039.SH
# 2019-02-01, BUY EXECUTED, ref:5743，Price: 42.49, Cost: 807.26, Comm 0.24, Size: 19.00, Stock: 600053.SH
# 2019-02-01, BUY EXECUTED, ref:5744，Price: 110.39, Cost: 1214.27, Comm 0.36, Size: 11.00, Stock: 600056.SH
# 2019-02-01, BUY EXECUTED, ref:5745，Price: 81.78, Cost: 817.78, Comm 0.25, Size: 10.00, Stock: 600062.SH
# 2019-02-01, BUY EXECUTED, ref:5746，Price: 31.43, Cost: 565.79, Comm 0.17, Size: 18.00, Stock: 600141.SH
# 2019-02-01, BUY EXECUTED, ref:5747，Price: 18.65, Cost: 540.81, Comm 0.16, Size: 29.00, Stock: 600151.SH
# 2019-02-01, BUY EXECUTED, ref:5748，Price: 54.15, Cost: 541.52, Comm 0.16, Size: 10.00, Stock: 600158.SH
# 2019-02-01, BUY EXECUTED, ref:5749，Price: 23.03, Cost: 575.75, Comm 0.17, Size: 25.00, Stock: 600169.SH
# 2019-02-01, BUY EXECUTED, ref:5750，Price: 21.24, Cost: 509.75, Comm 0.15, Size: 24.00, Stock: 600259.SH
# 2019-02-01, BUY EXECUTED, ref:5751，Price: 73.78, Cost: 1032.98, Comm 0.31, Size: 14.00, Stock: 600260.SH
# 2019-02-01, BUY EXECUTED, ref:5752，Price: 41.31, Cost: 371.76, Comm 0.11, Size: 9.00, Stock: 600280.SH
# 2019-02-01, BUY EXECUTED, ref:5753，Price: 58.18, Cost: 465.48, Comm 0.14, Size: 8.00, Stock: 600366.SH
# 2019-02-01, BUY EXECUTED, ref:5754，Price: 52.25, Cost: 1724.33, Comm 0.52, Size: 33.00, Stock: 600373.SH
# 2019-02-01, BUY EXECUTED, ref:5755，Price: 83.18, Cost: 1164.47, Comm 0.35, Size: 14.00, Stock: 600392.SH
# 2019-02-01, BUY EXECUTED, ref:5756，Price: 18.97, Cost: 189.68, Comm 0.06, Size: 10.00, Stock: 600393.SH
# 2019-02-01, BUY EXECUTED, ref:5757，Price: 20.62, Cost: 536.10, Comm 0.16, Size: 26.00, Stock: 600428.SH
# 2019-02-01, BUY EXECUTED, ref:5758，Price: 43.77, Cost: 612.80, Comm 0.18, Size: 14.00, Stock: 600478.SH
# 2019-02-01, BUY EXECUTED, ref:5759，Price: 42.68, Cost: 1408.42, Comm 0.42, Size: 33.00, Stock: 600500.SH
# 2019-02-01, BUY EXECUTED, ref:5760，Price: 53.50, Cost: 534.96, Comm 0.16, Size: 10.00, Stock: 600525.SH
# 2019-02-01, BUY EXECUTED, ref:5761，Price: 47.30, Cost: 1939.29, Comm 0.58, Size: 41.00, Stock: 600528.SH
# 2019-02-01, BUY EXECUTED, ref:5762，Price: 122.90, Cost: 1351.92, Comm 0.41, Size: 11.00, Stock: 600582.SH
# 2019-02-01, BUY EXECUTED, ref:5763，Price: 19.20, Cost: 1440.27, Comm 0.43, Size: 75.00, Stock: 600598.SH
# 2019-02-01, BUY EXECUTED, ref:5764，Price: 61.32, Cost: 1165.10, Comm 0.35, Size: 19.00, Stock: 600643.SH
# 2019-02-01, BUY EXECUTED, ref:5765，Price: 66.07, Cost: 594.63, Comm 0.18, Size: 9.00, Stock: 600657.SH
# 2019-02-01, BUY EXECUTED, ref:5766，Price: 83.62, Cost: 1087.01, Comm 0.33, Size: 13.00, Stock: 600729.SH
# 2019-02-01, BUY EXECUTED, ref:5767，Price: 77.02, Cost: 1386.43, Comm 0.42, Size: 18.00, Stock: 600737.SH
# 2019-02-01, BUY EXECUTED, ref:5768，Price: 73.85, Cost: 590.77, Comm 0.18, Size: 8.00, Stock: 600765.SH
# 2019-02-01, BUY EXECUTED, ref:5769，Price: 114.71, Cost: 1720.59, Comm 0.52, Size: 15.00, Stock: 600801.SH
# 2019-02-01, BUY EXECUTED, ref:5770，Price: 7.00, Cost: 2149.83, Comm 0.64, Size: 307.00, Stock: 600808.SH
# 2019-02-01, BUY EXECUTED, ref:5771，Price: 114.61, Cost: 1948.44, Comm 0.58, Size: 17.00, Stock: 600820.SH
# 2019-02-01, BUY EXECUTED, ref:5772，Price: 63.04, Cost: 504.31, Comm 0.15, Size: 8.00, Stock: 600859.SH
# 2019-02-01, BUY EXECUTED, ref:5773，Price: 337.24, Cost: 2360.67, Comm 0.71, Size: 7.00, Stock: 600872.SH
# 2019-02-01, BUY EXECUTED, ref:5774，Price: 27.73, Cost: 1830.04, Comm 0.55, Size: 66.00, Stock: 600875.SH
# 2019-02-01, BUY EXECUTED, ref:5775，Price: 97.41, Cost: 1850.71, Comm 0.56, Size: 19.00, Stock: 600885.SH
# 2019-02-01, BUY EXECUTED, ref:5776，Price: 4.57, Cost: 182.71, Comm 0.05, Size: 40.00, Stock: 600939.SH
# 2019-02-01, BUY EXECUTED, ref:5777，Price: 67.44, Cost: 944.21, Comm 0.28, Size: 14.00, Stock: 600970.SH
# 2019-02-01, BUY EXECUTED, ref:5778，Price: 8.26, Cost: 338.75, Comm 0.10, Size: 41.00, Stock: 601019.SH
# 2019-02-01, BUY EXECUTED, ref:5779，Price: 8.33, Cost: 224.90, Comm 0.07, Size: 27.00, Stock: 601020.SH
# 2019-02-01, BUY EXECUTED, ref:5780，Price: 6.05, Cost: 1289.29, Comm 0.39, Size: 213.00, Stock: 601168.SH
# 2019-02-01, BUY EXECUTED, ref:5781，Price: 14.75, Cost: 1313.02, Comm 0.39, Size: 89.00, Stock: 601801.SH
# 2019-02-01, BUY EXECUTED, ref:5782，Price: 23.24, Cost: 185.91, Comm 0.06, Size: 8.00, Stock: 603225.SH
# 2019-02-01, BUY EXECUTED, ref:5783，Price: 39.37, Cost: 236.24, Comm 0.07, Size: 6.00, Stock: 603233.SH
# 2019-02-01, BUY EXECUTED, ref:5784，Price: 23.37, Cost: 841.43, Comm 0.25, Size: 36.00, Stock: 603355.SH
# 2019-02-01, BUY EXECUTED, ref:5785，Price: 35.39, Cost: 318.52, Comm 0.10, Size: 9.00, Stock: 603515.SH
# 2019-02-01, BUY EXECUTED, ref:5786，Price: 31.10, Cost: 1368.57, Comm 0.41, Size: 44.00, Stock: 603568.SH
# 2019-03-01, SELL EXECUTED, ref:5812, Price: 27.12, Cost: 509.75, Comm 0.20, Size: -24.00, Stock: 600259.SH
# 2019-03-01, SELL EXECUTED, ref:5813, Price: 101.17, Cost: 1164.47, Comm 0.42, Size: -14.00, Stock: 600392.SH
# 2019-03-01, SELL EXECUTED, ref:5814, Price: 48.78, Cost: 1408.42, Comm 0.48, Size: -33.00, Stock: 600500.SH
# 2019-03-01, SELL EXECUTED, ref:5815, Price: 87.23, Cost: 1165.10, Comm 0.50, Size: -19.00, Stock: 600643.SH
# 2019-03-01, SELL EXECUTED, ref:5816, Price: 93.17, Cost: 1386.43, Comm 0.50, Size: -18.00, Stock: 600737.SH
# 2019-03-01, SELL EXECUTED, ref:5817, Price: 29.48, Cost: 1830.04, Comm 0.58, Size: -66.00, Stock: 600875.SH
# 2019-03-01, SELL EXECUTED, ref:5818, Price: 82.40, Cost: 944.21, Comm 0.35, Size: -14.00, Stock: 600970.SH
# 2019-03-01, SELL EXECUTED, ref:5819, Price: 7.18, Cost: 1289.29, Comm 0.46, Size: -213.00, Stock: 601168.SH
# 2019-03-01, SELL EXECUTED, ref:5820, Price: 44.19, Cost: 236.24, Comm 0.08, Size: -6.00, Stock: 603233.SH
# 2019-03-01, SELL EXECUTED, ref:5821, Price: 39.99, Cost: 318.52, Comm 0.11, Size: -9.00, Stock: 603515.SH
# 2019-03-01, SELL EXECUTED, ref:5822, Price: 58.92, Cost: 1189.33, Comm 0.44, Size: -25.00, Stock: 603883.SH
# 2019-03-01, BUY EXECUTED, ref:5823，Price: 71.45, Cost: 714.46, Comm 0.21, Size: 10.00, Stock: 000501.SZ
# 2019-03-01, BUY EXECUTED, ref:5824，Price: 81.95, Cost: 983.43, Comm 0.30, Size: 12.00, Stock: 000528.SZ
# 2019-03-01, BUY EXECUTED, ref:5825，Price: 50.90, Cost: 305.39, Comm 0.09, Size: 6.00, Stock: 000537.SZ
# 2019-03-01, SELL EXECUTED, ref:5826, Price: 37.32, Cost: 35.60, Comm 0.01, Size: -1.00, Stock: 000656.SZ
# 2019-03-01, BUY EXECUTED, ref:5827，Price: 174.63, Cost: 1397.01, Comm 0.42, Size: 8.00, Stock: 000998.SZ
# 2019-03-01, BUY EXECUTED, ref:5828，Price: 74.77, Cost: 822.47, Comm 0.25, Size: 11.00, Stock: 002176.SZ
# 2019-03-01, BUY EXECUTED, ref:5829，Price: 36.01, Cost: 1296.35, Comm 0.39, Size: 36.00, Stock: 002221.SZ
# 2019-03-01, BUY EXECUTED, ref:5830，Price: 65.04, Cost: 650.39, Comm 0.20, Size: 10.00, Stock: 002254.SZ
# 2019-03-01, BUY EXECUTED, ref:5831，Price: 15.95, Cost: 366.86, Comm 0.11, Size: 23.00, Stock: 002354.SZ
# 2019-03-01, BUY EXECUTED, ref:5832，Price: 33.20, Cost: 663.91, Comm 0.20, Size: 20.00, Stock: 002366.SZ
# 2019-03-01, BUY EXECUTED, ref:5833，Price: 107.35, Cost: 1932.34, Comm 0.58, Size: 18.00, Stock: 002372.SZ
# 2019-03-01, BUY EXECUTED, ref:5834，Price: 61.30, Cost: 1226.03, Comm 0.37, Size: 20.00, Stock: 002373.SZ
# 2019-03-01, BUY EXECUTED, ref:5835，Price: 15.42, Cost: 678.31, Comm 0.20, Size: 44.00, Stock: 002416.SZ
# 2019-03-01, BUY EXECUTED, ref:5836，Price: 213.33, Cost: 1493.29, Comm 0.45, Size: 7.00, Stock: 002439.SZ
# 2019-03-01, BUY EXECUTED, ref:5837，Price: 27.01, Cost: 2620.40, Comm 0.79, Size: 97.00, Stock: 002506.SZ
# 2019-03-01, BUY EXECUTED, ref:5838，Price: 37.42, Cost: 261.91, Comm 0.08, Size: 7.00, Stock: 300156.SZ
# 2019-03-01, BUY EXECUTED, ref:5839，Price: 61.97, Cost: 557.72, Comm 0.17, Size: 9.00, Stock: 300459.SZ
# 2019-03-01, BUY EXECUTED, ref:5840，Price: 55.55, Cost: 1222.16, Comm 0.37, Size: 22.00, Stock: 600060.SH
# 2019-03-01, BUY EXECUTED, ref:5841，Price: 36.20, Cost: 108.59, Comm 0.03, Size: 3.00, Stock: 600141.SH
# 2019-03-01, BUY EXECUTED, ref:5842，Price: 80.43, Cost: 2010.67, Comm 0.60, Size: 25.00, Stock: 600160.SH
# 2019-03-01, BUY EXECUTED, ref:5843，Price: 32.28, Cost: 774.61, Comm 0.23, Size: 24.00, Stock: 600171.SH
# 2019-03-01, BUY EXECUTED, ref:5844，Price: 136.61, Cost: 2458.89, Comm 0.74, Size: 18.00, Stock: 600183.SH
# 2019-03-01, BUY EXECUTED, ref:5845，Price: 44.22, Cost: 707.57, Comm 0.21, Size: 16.00, Stock: 600195.SH
# 2019-03-01, BUY EXECUTED, ref:5846，Price: 168.05, Cost: 2016.65, Comm 0.60, Size: 12.00, Stock: 600315.SH
# 2019-03-01, BUY EXECUTED, ref:5847，Price: 24.60, Cost: 172.23, Comm 0.05, Size: 7.00, Stock: 600428.SH
# 2019-03-01, BUY EXECUTED, ref:5848，Price: 38.68, Cost: 1818.07, Comm 0.55, Size: 47.00, Stock: 600466.SH
# 2019-03-01, BUY EXECUTED, ref:5849，Price: 153.07, Cost: 1377.64, Comm 0.41, Size: 9.00, Stock: 600536.SH
# 2019-03-01, BUY EXECUTED, ref:5850，Price: 146.29, Cost: 1316.64, Comm 0.39, Size: 9.00, Stock: 600717.SH
# 2019-03-01, BUY EXECUTED, ref:5851，Price: 185.54, Cost: 742.17, Comm 0.22, Size: 4.00, Stock: 600750.SH
# 2019-03-01, SELL EXECUTED, ref:5852, Price: 7.66, Cost: 28.01, Comm 0.01, Size: -4.00, Stock: 600808.SH
# 2019-03-01, BUY EXECUTED, ref:5853，Price: 175.35, Cost: 526.04, Comm 0.16, Size: 3.00, Stock: 600993.SH
# 2019-03-01, BUY EXECUTED, ref:5854，Price: 47.47, Cost: 332.27, Comm 0.10, Size: 7.00, Stock: 601869.SH
# 2019-03-01, BUY EXECUTED, ref:5855，Price: 24.71, Cost: 1013.01, Comm 0.30, Size: 41.00, Stock: 603025.SH
# 2019-04-01, SELL EXECUTED, ref:5901, Price: 12.64, Cost: 30.67, Comm 0.02, Size: -5.00, Stock: 000536.SZ
# 2019-04-01, BUY EXECUTED, ref:5902，Price: 89.87, Cost: 1797.43, Comm 0.54, Size: 20.00, Stock: 000563.SZ
# 2019-04-01, BUY EXECUTED, ref:5903，Price: 11.09, Cost: 620.79, Comm 0.19, Size: 56.00, Stock: 000564.SZ
# 2019-04-01, BUY EXECUTED, ref:5904，Price: 104.35, Cost: 1669.59, Comm 0.50, Size: 16.00, Stock: 000581.SZ
# 2019-04-01, BUY EXECUTED, ref:5905，Price: 263.74, Cost: 1054.97, Comm 0.32, Size: 4.00, Stock: 000636.SZ
# 2019-04-01, SELL EXECUTED, ref:5906, Price: 45.10, Cost: 249.23, Comm 0.09, Size: -7.00, Stock: 000656.SZ
# 2019-04-01, BUY EXECUTED, ref:5907，Price: 15.22, Cost: 699.90, Comm 0.21, Size: 46.00, Stock: 000727.SZ
# 2019-04-01, BUY EXECUTED, ref:5908，Price: 74.43, Cost: 893.12, Comm 0.27, Size: 12.00, Stock: 000877.SZ
# 2019-04-01, BUY EXECUTED, ref:5909，Price: 108.75, Cost: 870.03, Comm 0.26, Size: 8.00, Stock: 002004.SZ
# 2019-04-01, SELL EXECUTED, ref:5910, Price: 21.12, Cost: 83.33, Comm 0.03, Size: -5.00, Stock: 002110.SZ
# 2019-04-01, SELL EXECUTED, ref:5911, Price: 41.55, Cost: 72.02, Comm 0.02, Size: -2.00, Stock: 002221.SZ
# 2019-04-01, BUY EXECUTED, ref:5912，Price: 27.31, Cost: 1146.98, Comm 0.34, Size: 42.00, Stock: 002244.SZ
# 2019-04-01, BUY EXECUTED, ref:5913，Price: 55.76, Cost: 724.94, Comm 0.22, Size: 13.00, Stock: 002266.SZ
# 2019-04-01, BUY EXECUTED, ref:5914，Price: 101.35, Cost: 1722.95, Comm 0.52, Size: 17.00, Stock: 002281.SZ
# 2019-04-01, BUY EXECUTED, ref:5915，Price: 24.14, Cost: 627.64, Comm 0.19, Size: 26.00, Stock: 002344.SZ
# 2019-04-01, SELL EXECUTED, ref:5916, Price: 16.41, Cost: 15.95, Comm 0.00, Size: -1.00, Stock: 002354.SZ
# 2019-04-01, BUY EXECUTED, ref:5917，Price: 142.79, Cost: 1285.13, Comm 0.39, Size: 9.00, Stock: 002368.SZ
# 2019-04-01, SELL EXECUTED, ref:5918, Price: 126.54, Cost: 107.35, Comm 0.04, Size: -1.00, Stock: 002372.SZ
# 2019-04-01, SELL EXECUTED, ref:5919, Price: 78.50, Cost: 61.30, Comm 0.02, Size: -1.00, Stock: 002373.SZ
# 2019-04-01, BUY EXECUTED, ref:5920，Price: 40.62, Cost: 731.20, Comm 0.22, Size: 18.00, Stock: 002375.SZ
# 2019-04-01, BUY EXECUTED, ref:5921，Price: 59.52, Cost: 833.32, Comm 0.25, Size: 14.00, Stock: 002390.SZ
# 2019-04-01, SELL EXECUTED, ref:5922, Price: 50.47, Cost: 75.65, Comm 0.03, Size: -2.00, Stock: 002408.SZ
# 2019-04-01, SELL EXECUTED, ref:5923, Price: 16.32, Cost: 46.25, Comm 0.01, Size: -3.00, Stock: 002416.SZ
# 2019-04-01, SELL EXECUTED, ref:5924, Price: 32.26, Cost: 110.13, Comm 0.05, Size: -5.00, Stock: 002463.SZ
# 2019-04-01, BUY EXECUTED, ref:5925，Price: 65.58, Cost: 1836.14, Comm 0.55, Size: 28.00, Stock: 002465.SZ
# 2019-04-01, BUY EXECUTED, ref:5926，Price: 31.85, Cost: 1815.54, Comm 0.54, Size: 57.00, Stock: 002470.SZ
# 2019-04-01, SELL EXECUTED, ref:5927, Price: 27.22, Cost: 216.12, Comm 0.07, Size: -8.00, Stock: 002506.SZ
# 2019-04-01, BUY EXECUTED, ref:5928，Price: 47.03, Cost: 282.20, Comm 0.08, Size: 6.00, Stock: 002588.SZ
# 2019-04-01, SELL EXECUTED, ref:5929, Price: 32.65, Cost: 23.16, Comm 0.01, Size: -1.00, Stock: 002642.SZ
# 2019-04-01, BUY EXECUTED, ref:5930，Price: 101.35, Cost: 810.80, Comm 0.24, Size: 8.00, Stock: 002690.SZ
# 2019-04-01, BUY EXECUTED, ref:5931，Price: 65.34, Cost: 522.71, Comm 0.16, Size: 8.00, Stock: 300287.SZ
# 2019-04-01, SELL EXECUTED, ref:5932, Price: 60.35, Cost: 55.55, Comm 0.02, Size: -1.00, Stock: 600060.SH
# 2019-04-01, BUY EXECUTED, ref:5933，Price: 104.57, Cost: 941.16, Comm 0.28, Size: 9.00, Stock: 600062.SH
# 2019-04-01, BUY EXECUTED, ref:5934，Price: 88.48, Cost: 1061.77, Comm 0.32, Size: 12.00, Stock: 600138.SH
# 2019-04-01, SELL EXECUTED, ref:5935, Price: 36.16, Cost: 32.11, Comm 0.01, Size: -1.00, Stock: 600141.SH
# 2019-04-01, BUY EXECUTED, ref:5936，Price: 104.57, Cost: 1254.80, Comm 0.38, Size: 12.00, Stock: 600143.SH
# 2019-04-01, BUY EXECUTED, ref:5937，Price: 228.70, Cost: 1829.56, Comm 0.55, Size: 8.00, Stock: 600161.SH
# 2019-04-01, SELL EXECUTED, ref:5938, Price: 41.23, Cost: 32.28, Comm 0.01, Size: -1.00, Stock: 600171.SH
# 2019-04-01, SELL EXECUTED, ref:5939, Price: 153.53, Cost: 136.61, Comm 0.05, Size: -1.00, Stock: 600183.SH
# 2019-04-01, BUY EXECUTED, ref:5940，Price: 269.45, Cost: 1616.70, Comm 0.49, Size: 6.00, Stock: 600201.SH
# 2019-04-01, BUY EXECUTED, ref:5941，Price: 77.11, Cost: 925.37, Comm 0.28, Size: 12.00, Stock: 600267.SH
# 2019-04-01, BUY EXECUTED, ref:5942，Price: 29.36, Cost: 1732.10, Comm 0.52, Size: 59.00, Stock: 600277.SH
# 2019-04-01, BUY EXECUTED, ref:5943，Price: 74.71, Cost: 672.42, Comm 0.20, Size: 9.00, Stock: 600458.SH
# 2019-04-01, SELL EXECUTED, ref:5944, Price: 46.14, Cost: 116.05, Comm 0.04, Size: -3.00, Stock: 600466.SH
# 2019-04-01, BUY EXECUTED, ref:5945，Price: 50.36, Cost: 1460.42, Comm 0.44, Size: 29.00, Stock: 600500.SH
# 2019-04-01, SELL EXECUTED, ref:5946, Price: 53.07, Cost: 141.90, Comm 0.05, Size: -3.00, Stock: 600528.SH
# 2019-04-01, SELL EXECUTED, ref:5947, Price: 22.90, Cost: 134.43, Comm 0.05, Size: -7.00, Stock: 600598.SH
# 2019-04-01, BUY EXECUTED, ref:5948，Price: 79.08, Cost: 1186.20, Comm 0.36, Size: 15.00, Stock: 600633.SH
# 2019-04-01, BUY EXECUTED, ref:5949，Price: 49.42, Cost: 2273.42, Comm 0.68, Size: 46.00, Stock: 600642.SH
# 2019-04-01, BUY EXECUTED, ref:5950，Price: 62.05, Cost: 1365.15, Comm 0.41, Size: 22.00, Stock: 600664.SH
# 2019-04-01, SELL EXECUTED, ref:5951, Price: 150.47, Cost: 114.71, Comm 0.05, Size: -1.00, Stock: 600801.SH
# 2019-04-01, SELL EXECUTED, ref:5952, Price: 7.62, Cost: 182.07, Comm 0.06, Size: -26.00, Stock: 600808.SH
# 2019-04-01, BUY EXECUTED, ref:5953，Price: 170.19, Cost: 1701.90, Comm 0.51, Size: 10.00, Stock: 600823.SH
# 2019-04-01, BUY EXECUTED, ref:5954，Price: 50.19, Cost: 1505.60, Comm 0.45, Size: 30.00, Stock: 600863.SH
# 2019-04-01, BUY EXECUTED, ref:5955，Price: 31.73, Cost: 1903.64, Comm 0.57, Size: 60.00, Stock: 600875.SH
# 2019-04-01, SELL EXECUTED, ref:5956, Price: 8.96, Cost: 24.79, Comm 0.01, Size: -3.00, Stock: 601019.SH
# 2019-04-01, BUY EXECUTED, ref:5957，Price: 74.27, Cost: 2599.44, Comm 0.78, Size: 35.00, Stock: 601100.SH
# 2019-04-01, BUY EXECUTED, ref:5958，Price: 3.96, Cost: 2305.00, Comm 0.69, Size: 582.00, Stock: 601106.SH
# 2019-04-01, BUY EXECUTED, ref:5959，Price: 7.35, Cost: 1403.56, Comm 0.42, Size: 191.00, Stock: 601168.SH
# 2019-04-01, BUY EXECUTED, ref:5960，Price: 4.55, Cost: 654.72, Comm 0.20, Size: 144.00, Stock: 601326.SH
# 2019-04-01, BUY EXECUTED, ref:5961，Price: 8.21, Cost: 2018.47, Comm 0.61, Size: 246.00, Stock: 601608.SH
# 2019-04-01, SELL EXECUTED, ref:5962, Price: 18.44, Cost: 118.02, Comm 0.04, Size: -8.00, Stock: 601801.SH
# 2019-04-01, SELL EXECUTED, ref:5963, Price: 25.20, Cost: 49.42, Comm 0.02, Size: -2.00, Stock: 603025.SH
# 2019-04-01, SELL EXECUTED, ref:5964, Price: 29.08, Cost: 70.12, Comm 0.03, Size: -3.00, Stock: 603355.SH
# 2019-04-01, SELL EXECUTED, ref:5965, Price: 38.34, Cost: 124.42, Comm 0.05, Size: -4.00, Stock: 603568.SH
